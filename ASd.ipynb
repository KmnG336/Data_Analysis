# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\Komen\\Downloads\\ASd\\World Cities Database Population (OCT-2022).csv", sep = ';', na_filter=False ) 
df.head(5)
# Out:
# C:\Users\Komen\anaconda3\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0,13,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   Geoname ID             Name       ASCII Name  \
# 0     509184         Pizhanka         Pizhanka
# 1     509273         Pitelino         Pitelino
# 2     510139  Petro-Slavyanka  Petro-Slavyanka
# 3     513051          Palkino          Palkino
# 4     514906          Orlovka          Orlovka
#
#                                      Alternate Names Feature Class  \
# 0                          Pizhanka,Pizjanka,Пижанка             P
# 1                         Petelino,Pitelino,Пителино             P
# 2  Petro-Slav'anka,Petro-Slavjanka,Petro-Slavyank...             P
# 3                            Palkino,Палкино,Պալկինո             P
# 4                                    Orlovka,Орловка             P
#
#   Feature Code Country Code     Country name EN Country Code 2 Admin1 Code  \
# 0          PPL           RU  Russian Federation                         33
# 1          PPL           RU  Russian Federation                         62
# 2          PPL           RU  Russian Federation                         66
# 3          PPL           RU  Russian Federation                         60
# 4          PPL           RU  Russian Federation                         70
#
#   Admin2 Code Admin3 Code Admin4 Code Population Elevation  \
# 0                                           3900
# 1                                           2355
# 2                                           1308
# 3                                           3112
# 4                                           3236
#
#   DIgital Elevation Model       Timezone Modification date  \
# 0                     122   Europe/Kirov        2012-01-17
# 1                     120  Europe/Moscow        2012-01-17
# 2                      17  Europe/Moscow        2016-12-20
# 3                      67  Europe/Moscow        2012-01-17
# 4                     115  Europe/Moscow        2012-01-17
#
#              LABEL EN  \
# 0  Russian Federation
# 1  Russian Federation
# 2  Russian Federation
# 3  Russian Federation
# 4  Russian Federation
#
#   Coordinates,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 0  57.46042,48.542,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,...
# 1  54.57768,41.81448,,,,,,,,,,,,,,,,,,,,,,,,,,,,,...
# 2  59.80222,30.50694,,,,,,,,,,,,,,,,,,,,,,,,,,,,,...
# 3  57.54089,28.01257,,,,,,,,,,,,,,,,,,,,,,,,,,,,,...
# 4  44.69139,44.17444,,,,,,,,,,,,,,,,,,,,,,,,,,,,,...

# %% [markdown]
# ## Data cleaning and preprocessing

# %%
column_names = list(df.columns)
column_names[-1] = 'Coordinates'
df.columns = column_names
df['Coordinates'] = df['Coordinates'].apply(lambda x: str(x).split(',')[:2])

# %%
df['Coordinates']
# Out:
# 0           [57.46042, 48.542]
# 1         [54.57768, 41.81448]
# 2         [59.80222, 30.50694]
# 3         [57.54089, 28.01257]
# 4         [44.69139, 44.17444]
#                   ...
# 140629    [45.72176, 33.23689]
# 140630    [48.14431, 30.82103]
# 140631    [44.93845, 35.15834]
# 140632    [51.50208, 23.93806]
# 140633    [46.30452, 29.01519]
# Name: Coordinates, Length: 140634, dtype: object

# %%
df
# Out:
#        Geoname ID             Name       ASCII Name  \
# 0          509184         Pizhanka         Pizhanka
# 1          509273         Pitelino         Pitelino
# 2          510139  Petro-Slavyanka  Petro-Slavyanka
# 3          513051          Palkino          Palkino
# 4          514906          Orlovka          Orlovka
# ...           ...              ...              ...
# 140629     693588         Slavnoye         Slavnoye
# 140630     693760   Syniukhyn Brid   Syniukhyn Brid
# 140631     694320     Shchebetovka     Shchebetovka
# 140632     694333           Shatsk           Shatsk
# 140633     694427         Serpneve         Serpneve
#
#                                           Alternate Names Feature Class  \
# 0                               Pizhanka,Pizjanka,Пижанка             P
# 1                              Petelino,Pitelino,Пителино             P
# 2       Petro-Slav'anka,Petro-Slavjanka,Petro-Slavyank...             P
# 3                                 Palkino,Палкино,Պալկինո             P
# 4                                         Orlovka,Орловка             P
# ...                                                   ...           ...
# 140629  Bakal Tatarskij,Slavne,Slavnoe,Slavnoye,Бака́л...             P
# 140630  Sinjukhin Brid,Sinjukhin Brod,Sinyukhin Brod,S...             P
# 140631  Otus,Otuz,Otuzy,Shchebetovka,Shebetovka,Shhebe...             P
# 140632  Shac'k,Shats'k,Shatsk,Shats’k,Szack,Шатск,Шатс...             P
# 140633  Leipzig,Ljajpcig,Sehrpnehveh,Serpneve,Serpnevo...             P
#
#        Feature Code Country Code     Country name EN Country Code 2  \
# 0               PPL           RU  Russian Federation
# 1               PPL           RU  Russian Federation
# 2               PPL           RU  Russian Federation
# 3               PPL           RU  Russian Federation
# 4               PPL           RU  Russian Federation
# ...             ...          ...                 ...            ...
# 140629        PPLA3           UA             Ukraine
# 140630          PPL           UA             Ukraine
# 140631          PPL           UA             Ukraine
# 140632          PPL           UA             Ukraine
# 140633          PPL           UA             Ukraine
#
#        Admin1 Code Admin2 Code Admin3 Code Admin4 Code Population Elevation  \
# 0               33                                           3900
# 1               62                                           2355
# 2               66                                           1308
# 3               60                                           3112
# 4               70                                           3236
# ...            ...         ...         ...         ...        ...       ...
# 140629          11      695741    11153039                    914         8
# 140630          16      697571                               1708        99
# 140631          11     8449683                               3442        79
# 140632          24                                           5266
# 140633          17      691821                               1774        52
#
#        DIgital Elevation Model           Timezone Modification date  \
# 0                          122       Europe/Kirov        2012-01-17
# 1                          120      Europe/Moscow        2012-01-17
# 2                           17      Europe/Moscow        2016-12-20
# 3                           67      Europe/Moscow        2012-01-17
# 4                          115      Europe/Moscow        2012-01-17
# ...                        ...                ...               ...
# 140629                      12  Europe/Simferopol        2016-08-11
# 140630                      99        Europe/Kyiv        2022-09-01
# 140631                      77  Europe/Simferopol        2021-05-07
# 140632                     167        Europe/Kyiv        2022-09-01
# 140633                      52        Europe/Kyiv        2022-09-01
#
#                   LABEL EN           Coordinates
# 0       Russian Federation    [57.46042, 48.542]
# 1       Russian Federation  [54.57768, 41.81448]
# 2       Russian Federation  [59.80222, 30.50694]
# 3       Russian Federation  [57.54089, 28.01257]
# 4       Russian Federation  [44.69139, 44.17444]
# ...                    ...                   ...
# 140629             Ukraine  [45.72176, 33.23689]
# 140630             Ukraine  [48.14431, 30.82103]
# 140631             Ukraine  [44.93845, 35.15834]
# 140632             Ukraine  [51.50208, 23.93806]
# 140633             Ukraine  [46.30452, 29.01519]
#
# [140634 rows x 20 columns]

# %%
df.head()
# Out:
#   Geoname ID             Name       ASCII Name  \
# 0     509184         Pizhanka         Pizhanka
# 1     509273         Pitelino         Pitelino
# 2     510139  Petro-Slavyanka  Petro-Slavyanka
# 3     513051          Palkino          Palkino
# 4     514906          Orlovka          Orlovka
#
#                                      Alternate Names Feature Class  \
# 0                          Pizhanka,Pizjanka,Пижанка             P
# 1                         Petelino,Pitelino,Пителино             P
# 2  Petro-Slav'anka,Petro-Slavjanka,Petro-Slavyank...             P
# 3                            Palkino,Палкино,Պալկինո             P
# 4                                    Orlovka,Орловка             P
#
#   Feature Code Country Code     Country name EN Country Code 2 Admin1 Code  \
# 0          PPL           RU  Russian Federation                         33
# 1          PPL           RU  Russian Federation                         62
# 2          PPL           RU  Russian Federation                         66
# 3          PPL           RU  Russian Federation                         60
# 4          PPL           RU  Russian Federation                         70
#
#   Admin2 Code Admin3 Code Admin4 Code Population Elevation  \
# 0                                           3900
# 1                                           2355
# 2                                           1308
# 3                                           3112
# 4                                           3236
#
#   DIgital Elevation Model       Timezone Modification date  \
# 0                     122   Europe/Kirov        2012-01-17
# 1                     120  Europe/Moscow        2012-01-17
# 2                      17  Europe/Moscow        2016-12-20
# 3                      67  Europe/Moscow        2012-01-17
# 4                     115  Europe/Moscow        2012-01-17
#
#              LABEL EN           Coordinates
# 0  Russian Federation    [57.46042, 48.542]
# 1  Russian Federation  [54.57768, 41.81448]
# 2  Russian Federation  [59.80222, 30.50694]
# 3  Russian Federation  [57.54089, 28.01257]
# 4  Russian Federation  [44.69139, 44.17444]

# %%
df.isnull().sum()
# Out:
# Geoname ID                 0
# Name                       0
# ASCII Name                 0
# Alternate Names            0
# Feature Class              0
# Feature Code               0
# Country Code               0
# Country name EN            0
# Country Code 2             0
# Admin1 Code                0
# Admin2 Code                0
# Admin3 Code                0
# Admin4 Code                0
# Population                 0
# Elevation                  0
# DIgital Elevation Model    0
# Timezone                   0
# Modification date          0
# LABEL EN                   0
# Coordinates                0
# dtype: int64

# %%
column_names
# Out:
# ['Geoname ID',
#  'Name',
#  'ASCII Name',
#  'Alternate Names',
#  'Feature Class',
#  'Feature Code',
#  'Country Code',
#  'Country name EN',
#  'Country Code 2',
#  'Admin1 Code',
#  'Admin2 Code',
#  'Admin3 Code',
#  'Admin4 Code',
#  'Population',
#  'Elevation',
#  'DIgital Elevation Model',
#  'Timezone',
#  'Modification date',
#  'LABEL EN',
#  'Coordinates']

# %%
df['Latitude'] = df['Coordinates'].apply(lambda x: x[0])
df['Longitude'] = df['Coordinates'].apply(lambda x: x[-1])

# %%
df['Latitude']
# Out:
# 0         57.46042
# 1         54.57768
# 2         59.80222
# 3         57.54089
# 4         44.69139
#             ...
# 140629    45.72176
# 140630    48.14431
# 140631    44.93845
# 140632    51.50208
# 140633    46.30452
# Name: Latitude, Length: 140634, dtype: object

# %%
df['Longitude']
# Out:
# 0           48.542
# 1         41.81448
# 2         30.50694
# 3         28.01257
# 4         44.17444
#             ...
# 140629    33.23689
# 140630    30.82103
# 140631    35.15834
# 140632    23.93806
# 140633    29.01519
# Name: Longitude, Length: 140634, dtype: object

# %%
df['Latitude'] = pd.to_numeric(df['Latitude'], errors = 'coerce')
df['Longitude'] = pd.to_numeric(df['Longitude'], errors = 'coerce')

# %%
df['Latitude']
# Out:
# 0         57.46042
# 1         54.57768
# 2         59.80222
# 3         57.54089
# 4         44.69139
#             ...
# 140629    45.72176
# 140630    48.14431
# 140631    44.93845
# 140632    51.50208
# 140633    46.30452
# Name: Latitude, Length: 140634, dtype: float64

# %%
df['Coordinates']
# Out:
# 0           [57.46042, 48.542]
# 1         [54.57768, 41.81448]
# 2         [59.80222, 30.50694]
# 3         [57.54089, 28.01257]
# 4         [44.69139, 44.17444]
#                   ...
# 140629    [45.72176, 33.23689]
# 140630    [48.14431, 30.82103]
# 140631    [44.93845, 35.15834]
# 140632    [51.50208, 23.93806]
# 140633    [46.30452, 29.01519]
# Name: Coordinates, Length: 140634, dtype: object

# %%
df['Country Code']
# Out:
# 0         RU
# 1         RU
# 2         RU
# 3         RU
# 4         RU
#           ..
# 140629    UA
# 140630    UA
# 140631    UA
# 140632    UA
# 140633    UA
# Name: Country Code, Length: 140634, dtype: object

# %%
df['Country Code'] = df['Country Code'].fillna('NA')
df['Country Code']
# Out:
# 0         RU
# 1         RU
# 2         RU
# 3         RU
# 4         RU
#           ..
# 140629    UA
# 140630    UA
# 140631    UA
# 140632    UA
# 140633    UA
# Name: Country Code, Length: 140634, dtype: object

# %% [markdown]
# ## converting population & elevation columns to numeric

# %%
df['Population'] = df['Population'].apply(lambda x: pd.to_numeric(x, errors = 'coerce'))

df['Elevation'] = df['Population'].apply(lambda x: pd.to_numeric(x, errors = 'coerce'))

# %%
df['Elevation']
# Out:
# 0         3900.0
# 1         2355.0
# 2         1308.0
# 3         3112.0
# 4         3236.0
#            ...
# 140629     914.0
# 140630    1708.0
# 140631    3442.0
# 140632    5266.0
# 140633    1774.0
# Name: Elevation, Length: 140634, dtype: float64

# %%
df.head()
# Out:
#   Geoname ID             Name       ASCII Name  \
# 0     509184         Pizhanka         Pizhanka
# 1     509273         Pitelino         Pitelino
# 2     510139  Petro-Slavyanka  Petro-Slavyanka
# 3     513051          Palkino          Palkino
# 4     514906          Orlovka          Orlovka
#
#                                      Alternate Names Feature Class  \
# 0                          Pizhanka,Pizjanka,Пижанка             P
# 1                         Petelino,Pitelino,Пителино             P
# 2  Petro-Slav'anka,Petro-Slavjanka,Petro-Slavyank...             P
# 3                            Palkino,Палкино,Պալկինո             P
# 4                                    Orlovka,Орловка             P
#
#   Feature Code Country Code     Country name EN Country Code 2 Admin1 Code  \
# 0          PPL           RU  Russian Federation                         33
# 1          PPL           RU  Russian Federation                         62
# 2          PPL           RU  Russian Federation                         66
# 3          PPL           RU  Russian Federation                         60
# 4          PPL           RU  Russian Federation                         70
#
#    ... Admin4 Code Population Elevation  DIgital Elevation Model  \
# 0  ...                 3900.0    3900.0                      122
# 1  ...                 2355.0    2355.0                      120
# 2  ...                 1308.0    1308.0                       17
# 3  ...                 3112.0    3112.0                       67
# 4  ...                 3236.0    3236.0                      115
#
#         Timezone Modification date            LABEL EN           Coordinates  \
# 0   Europe/Kirov        2012-01-17  Russian Federation    [57.46042, 48.542]
# 1  Europe/Moscow        2012-01-17  Russian Federation  [54.57768, 41.81448]
# 2  Europe/Moscow        2016-12-20  Russian Federation  [59.80222, 30.50694]
# 3  Europe/Moscow        2012-01-17  Russian Federation  [57.54089, 28.01257]
# 4  Europe/Moscow        2012-01-17  Russian Federation  [44.69139, 44.17444]
#
#    Latitude Longitude
# 0  57.46042  48.54200
# 1  54.57768  41.81448
# 2  59.80222  30.50694
# 3  57.54089  28.01257
# 4  44.69139  44.17444
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Dropping the columns that are not needed

# %%
df = df.iloc[:, [1,2,3,6,7,-9,-8,-6,-4,-2,-1]]

# %%
df.isna().sum()
# Out:
# Name               0
# ASCII Name         0
# Alternate Names    0
# Country Code       0
# Country name EN    0
# Population         1
# Elevation          1
# Timezone           0
# LABEL EN           0
# Latitude           2
# Longitude          2
# dtype: int64

# %%
df.to_csv('Population_cleaned.csv', sep = ',', index = False)

# %%
df.head()
# Out:
#               Name       ASCII Name  \
# 0         Pizhanka         Pizhanka
# 1         Pitelino         Pitelino
# 2  Petro-Slavyanka  Petro-Slavyanka
# 3          Palkino          Palkino
# 4          Orlovka          Orlovka
#
#                                      Alternate Names Country Code  \
# 0                          Pizhanka,Pizjanka,Пижанка           RU
# 1                         Petelino,Pitelino,Пителино           RU
# 2  Petro-Slav'anka,Petro-Slavjanka,Petro-Slavyank...           RU
# 3                            Palkino,Палкино,Պալկինո           RU
# 4                                    Orlovka,Орловка           RU
#
#       Country name EN  Population  Elevation       Timezone  \
# 0  Russian Federation      3900.0     3900.0   Europe/Kirov
# 1  Russian Federation      2355.0     2355.0  Europe/Moscow
# 2  Russian Federation      1308.0     1308.0  Europe/Moscow
# 3  Russian Federation      3112.0     3112.0  Europe/Moscow
# 4  Russian Federation      3236.0     3236.0  Europe/Moscow
#
#              LABEL EN  Latitude  Longitude
# 0  Russian Federation  57.46042   48.54200
# 1  Russian Federation  54.57768   41.81448
# 2  Russian Federation  59.80222   30.50694
# 3  Russian Federation  57.54089   28.01257
# 4  Russian Federation  44.69139   44.17444
